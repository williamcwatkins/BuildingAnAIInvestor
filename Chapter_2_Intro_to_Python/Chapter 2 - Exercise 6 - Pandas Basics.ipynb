# %% [markdown]
# # Exercise 6 – Pandas Basics

# %%
# Code from Book: Build Your Own AI Investor
# Damon Lee 2021
# Check out the performance on www.valueinvestingai.com
# Code uses data from the (presumably) nice people at https://simfin.com/. 
# Feel free to fork this code for others to see what can be done with it.

# %%
# Set the plotting DPI settings to be a bit higher.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [8.0, 5.0]
plt.rcParams['figure.dpi'] = 150

# %%
#Import Pandas
import pandas as pd

# %%
#Creating a dictionary with some table data in it.
dict = {
    'Name':['Tom', 'Dick', 'Harry'],
    'Age':[24, 35, 29],
    'Shoe Size':[7,8,9]
}

# %%
#Creating a DataFrame with the data from the dictionary
df=pd.DataFrame(dict)

# %%
#The dataframe can be viewed without the print() command.
df
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %%
#Write the data from the DataFrame to a file
df.to_csv('people.csv')

# %%
# Now I want to read the data, lets create a new DataFrame. Remember to specify an index column!
my_data=pd.read_csv('people.csv', index_col=0)

# %%
#have a look at the data
my_data
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %% [markdown]
# # Read in SimFin data

# %%
# Lets read some income statement data from SimFin (https://simfin.com/)
# Your download directory will differ.
Income_Data=pd.read_csv(\
    'us-income-annual.csv',\
                        delimiter=';')

# %%
# get the DataFrame shape (Might be useful for other computation)
print('DataFrame shape is: ',Income_Data.shape)
#Have a look at what our DataFrame looks like
Income_Data
# You will notice that thefirst few and last few items are shown (Jupyter doesn't want to display all 15,124 rows.)
# Out:
# DataFrame shape is:  (16834, 28)
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2017            FY  2017-10-31
# 1          A     45846      USD         2018            FY  2018-10-31
# 2          A     45846      USD         2019            FY  2019-10-31
# 3          A     45846      USD         2020            FY  2020-10-31
# 4          A     45846      USD         2021            FY  2021-10-31
# ...      ...       ...      ...          ...           ...         ...
# 16829   ZYXI    171401      USD         2017            FY  2017-12-31
# 16830   ZYXI    171401      USD         2018            FY  2018-12-31
# 16831   ZYXI    171401      USD         2019            FY  2019-12-31
# 16832   ZYXI    171401      USD         2020            FY  2020-12-31
# 16833   ZYXI    171401      USD         2021            FY  2021-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 1       2018-12-20    2020-12-18     321000000.0       325000000.0  ...
# 2       2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 3       2020-12-18    2022-12-21     309000000.0       312000000.0  ...
# 4       2021-12-17    2022-12-21     305000000.0       307000000.0  ...
# ...            ...           ...             ...               ...  ...
# 16829   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
# 16830   2019-02-26    2019-02-26      35753300.0        37447300.0  ...
# 16831   2020-02-27    2021-02-25      35682900.0        37359300.0  ...
# 16832   2021-02-25    2022-03-22      37255900.0        38437300.0  ...
# 16833   2022-03-22    2023-03-14      37255900.0        38437300.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                      -38000000.0            -57000000.0
# 1                       42000000.0            -37000000.0
# 2                      -22000000.0            -38000000.0
# 3                       -4000000.0            -70000000.0
# 4                       13000000.0            -79000000.0
# ...                            ...                    ...
# 16829                   -1450000.0             -1450000.0
# 16830                    -154000.0              -154000.0
# 16831                      -5000.0                -5000.0
# 16832                     -19000.0               -19000.0
# 16833                     -95000.0               -95000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       803000000                      NaN
# 1                       946000000                      NaN
# 2                       919000000                      NaN
# 3                       842000000                      NaN
# 4                      1360000000                      NaN
# ...                           ...                      ...
# 16829                     7494000                      NaN
# 16830                    10216000                      NaN
# 16831                    11061000                 880000.0
# 16832                    10230000                 -77000.0
# 16833                    22271000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 803000000                       -119000000.0
# 1                 946000000                       -630000000.0
# 2                 919000000                        152000000.0
# 3                 842000000                       -123000000.0
# 4                1360000000                       -150000000.0
# ...                     ...                                ...
# 16829               7494000                          -129000.0
# 16830              10216000                          -664000.0
# 16831              11941000                         -2449000.0
# 16832              10153000                         -1079000.0
# 16833              22271000                         -5168000.0
#
#        Income (Loss) from Continuing Operations  \
# 0                                     684000000
# 1                                     316000000
# 2                                    1071000000
# 3                                     719000000
# 4                                    1210000000
# ...                                         ...
# 16829                                   7365000
# 16830                                   9552000
# 16831                                   9492000
# 16832                                   9074000
# 16833                                  17103000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   684000000            684000000
# 1                                   NaN   316000000            316000000
# 2                                   NaN  1071000000           1071000000
# 3                                   NaN   719000000            719000000
# 4                                   NaN  1210000000           1210000000
# ...                                 ...         ...                  ...
# 16829                               NaN     7365000              7365000
# 16830                               NaN     9552000              9552000
# 16831                               NaN     9492000              9492000
# 16832                               NaN     9074000              9074000
# 16833                               NaN    17103000             17103000
#
# [16834 rows x 28 columns]

# %%
# The headings of columns are called keys. 
# The columns themselves are called series.
# To see what all the columns are in our dataframe, use the .keys() function. 
print(Income_Data.keys())
# Out:
# Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')

# %%
# To see series data for a single key:
Income_Data['Ticker']
# Out:
# 0           A
# 1           A
# 2           A
# 3           A
# 4           A
#          ...
# 16829    ZYXI
# 16830    ZYXI
# 16831    ZYXI
# 16832    ZYXI
# 16833    ZYXI
# Name: Ticker, Length: 16834, dtype: object

# %%
Income_Data['Report Date']
# Out:
# 0        2017-10-31
# 1        2018-10-31
# 2        2019-10-31
# 3        2020-10-31
# 4        2021-10-31
#             ...
# 16829    2017-12-31
# 16830    2018-12-31
# 16831    2019-12-31
# 16832    2020-12-31
# 16833    2021-12-31
# Name: Report Date, Length: 16834, dtype: object

# %%
print('The resulting type of object from our series selection is a:', type(Income_Data['Report Date']) )
print('using .values after our selection turns this into a:', type(Income_Data['Report Date'].values) )
# Out:
# The resulting type of object from our series selection is a: <class 'pandas.core.series.Series'>
# using .values after our selection turns this into a: <class 'numpy.ndarray'>

# %%
# To get a list of tickers that exist, we could use the set operations we learned earlier.
my_set = set(Income_Data['Ticker'].values)
print(my_set)
# Out:
# {'FKWL', 'NX', 'ENPH', 'AURA', 'TKAT', 'DENN', 'ABNB', 'SQBG', 'CVNA', 'AUGX', 'SBRA', 'TPCS', 'TRVI', 'HCVI', 'KMX', 'RENN', 'CSSE', 'PYXS', 'PERI', 'ALOT', 'MRMD', 'NGVT', 'INFI', 'PSN', 'BURL', 'FWRG', 'LYTS', 'PDEX', 'VSEC', 'MAPS', 'AMH', 'NTST', 'ADM', 'WCC', 'CNC', 'VG', 'ARNC', 'CALA', 'ITT', 'JRSH', 'ATRC', 'NSC', 'CIFR', 'CPNG', 'TLYS', 'FMC', 'BROS', 'ORBC', 'ATNX', 'HLX', 'LLY', 'VIVK', 'HEES', 'APHE', 'CCOI', 'TMUS', 'MGM', 'NWN', 'LAWS', 'TG', 'ALCO', 'AMRX', 'FANG', 'QGEN', 'CVII', 'PSA', 'BIO', 'PEP', 'IVAC', 'SIG', 'HI', 'REV', 'NOK', 'PRFT', 'BGNE', 'DX', 'MOH', 'EPRT', 'NTUS', 'KLIC', 'CNTG', 'FSII', 'AVID', 'DOUG', 'PATH', 'AMBA', 'PVH', 'FTCO', 'ATEX', 'SBH', 'LTC', 'CERE', 'BH', 'ACRO', 'ATOS', 'PMD', 'SOTK', 'BAND', 'BVH', 'CDW', 'TNYA', 'MRSN', 'TWLO', 'GTHX', 'CHRS', 'MTW', 'NRDS', 'CHART', 'MNPR', 'RYTM', 'GMS', 'SAVA', 'SWAV', 'TSQ', 'FEIM', 'HY', 'ONVO', 'LTRPA', 'LUMN', 'RMAX', 'AVDL', 'MGPI', 'BCAB', 'ANAB', 'ERES', 'NGM', 'AZPN', 'PBF', 'GBX', 'STAY', 'ZNOG', 'CLCT', 'EG', 'MTN', 'ZAYO', 'NGVC', 'AKTX', 'SWI', 'PNR', 'RPM', 'CDEV', 'VMC', 'CBIO', 'POR', 'SAR', 'UNH', 'HOFT', 'PRGO', 'LAC', 'ACET', 'CGNX', 'CC', 'VERX', 'SNAP', 'TPR', 'BOXL', 'ECOM', 'HON', 'NSTB', 'AVA', 'SMID', 'RM', 'ISDR', 'PECO', 'PNM', 'NJR', 'CRSR', 'LAND', 'NVDA', 'LKQ', 'ATRA', 'WLL', 'PFIE', 'CPUH', 'SPIR', 'VRML', 'BEN', 'NMRK', 'RS', 'MESA', 'SOPA', 'AUVI', 'VRTU', 'MARA', 'RXDX', 'CHK', 'IMVT', 'PIRS', 'BIIB', 'CNLPL', 'HPE', 'PI', 'PRGS', 'SMG', 'GRUB', 'MNK', 'PSPC', 'DMLP', 'AGEN', 'HYBT', 'CIX', 'PFGC', 'STKS', 'ATKR', 'HES', 'ETM', 'SORL', 'SNX', 'PCVX', 'ADUS', 'CIR', 'LANC', 'REKR', 'VSH', 'XRAY', 'ADNT', 'LORL', 'TTCF', 'USAU', 'BRIV', 'AFRM', 'CIO', 'PHX', 'CRWS', 'ULBI', 'AVTR', 'PACK', 'SEM', 'TAYD', 'JYNT', 'SNH', 'BMI', 'DHR', 'TTSH', 'TTMI', 'DBI', 'DNB', 'LMT', 'OOMA', 'RAVN', 'THRX', 'LXU', 'VPG', 'VRCA', 'PCTY', 'INNV', 'TYGO', 'NWE', 'CCH', 'OA', 'PFMT', 'MNI', 'PVAC', 'CCK', 'IT', 'TER', 'TGT', 'TEUM', 'MRTN', 'COKE', 'ON', 'CRL', 'VIRX', 'VSTO', 'CTGO', 'ABSI', 'XXII', 'TBTC', 'BLCM', 'INAB', 'LBPH', 'LDOS', 'SNCY', 'OMED', 'AERC', 'PROG', 'ICVX', 'TPC', 'SPLS', 'RH', 'CANO', 'MTD', 'DSKE', 'SSI', 'FLEX', 'IRM', 'AAC', 'ENVA', 'IVZ', 'GRWG', 'SSNT', 'KRMD', 'FLWS', 'SWCH', 'HOLX', 'ALJJ', 'VIVE', 'LASR', 'NC', 'ZY', 'FARO', 'OPAD', 'GTLS', 'ARKR', 'VERI', 'Y', 'OMH', 'TAP', 'KROS', 'RMR', 'TCS', 'AMTD', 'MCK', 'INTT', 'EYE', 'PM', 'SGMA', 'PKE', 'GPS', 'FTPAU', 'AMPS', 'CWST', 'OUST', 'CREX', 'PRCT', 'REN', 'NICK', 'TRC', 'ASAN', 'NVR', 'SGC', 'WMK', 'WTS', 'SUPN', 'AZO', 'WRI', 'DE', 'ABTL', 'LIVN', 'SINT', 'APRE', 'GSHD', 'TIS', 'TREC', 'KR', 'JOE', 'VSAT', 'VHI', 'CSBR', 'ELYM', 'AMED', 'CATM', 'EVI', 'EYPT', 'GPK', 'IRIX', 'MTTR', 'OPK', 'DCI', 'LNDC', 'LOCO', 'NCNO', 'S_delisted', 'WDQ', 'CFRX', 'WHD', 'NAT', 'HNGR', 'ALEC', 'ZVO', 'CLGX', 'IDSY', 'LUNG', 'NEXI', 'CLX', 'RMBL', 'COHU', 'KTEC_delis', 'MICR', 'WVE', 'VRM', 'AKS', 'AGIO', 'EFX', 'KEGX', 'REPL', 'GEG', 'ZYXI', 'COO', 'GDRX', 'EPAM', 'NUVL', 'PINC', 'KRC', 'WNDW', 'SONO', 'ROIV', 'BBGI', 'CTRN', 'HUYA', 'QNST', 'DKS', 'BIGC', 'SEAS', 'CVRX', 'TST', 'BCOV', 'FOX_old', 'NEP', 'ZNTL', 'GRPH', 'MSTR', 'RLYB', 'NP', 'WAIR', 'NRDY', 'AAIC', 'EKSO', 'SKIN', 'CLF', 'MIND', 'NEM', 'SBUX', 'SPRO', 'NEE', 'ALIM', 'KELYA', 'TWCB', 'ADER', 'EDIT', 'LPTV', 'DSGN', 'ELS', 'WDFC', 'AMWD', 'FLGT', 'NKLA', 'TROX', 'TRNS', 'SOHO', 'RVPH', 'ERII', 'DOCN', 'BRKS', 'LGND', 'MASS', 'PCH', 'EAF', 'SVU', 'EMKR', 'AES', 'HEI', 'KNSA', 'ZEUS', 'GNE', 'PLTR', 'SFLY', 'HXL', 'WMGI_delis', 'APTV', 'EZOO', 'TEP', 'BF-A', 'IGT', 'EVHC', 'RELY', 'IVTY', 'GME', 'HRB', 'KDP', 'GOEV', 'CPAAU', 'CTSO', 'STLD', 'ZVIA', 'CPRI', 'ASTS', 'CRGE', 'LMAT', 'QDEL', 'WEX', 'AKR', 'TGLS', 'QVC', 'CLXT', 'PRCH', 'IRTC', 'PRTS', 'TILE', 'AIR', 'CFLT', 'CNK', 'GRTS', 'FL', 'CAAS', 'LLNW', 'AMCX', 'AGCO', 'KOS', 'LLPP', 'BZUN', 'NVTA', 'SWKH', 'VEEV', 'ANIX', 'EBS', 'RIOT', 'IPWR', 'IVDN', 'JACK', 'ODC', 'PSTX', 'CLBR', 'RMCF', 'TJX', 'VER', 'NVT', 'FRSH', 'SRT', 'MTZ', 'ADPT', 'NP ...

# %%
#Alternatively a dataframe has a function .unique()
Income_Data['Ticker'].unique()
# Out:
# array(['A', 'A18', 'A21', ..., 'ZY', 'ZYNE', 'ZYXI'], dtype=object)

# %%
# You can use logic on dataframes to obtain a list of boolean values that say whether a rule is True or False for each row.
# Let's try and isolate financial data for the 2017 fiscal period. 
# We will do a boolean check on items in the 'Fiscal Year' column:

IsIt2017 = (Income_Data['Fiscal Year'] == 2017)
print('The boolean logic on the Fiscal Year column is: ', IsIt2017)
# Out:
# The boolean logic on the Fiscal Year column is:  0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16829     True
# 16830    False
# 16831    False
# 16832    False
# 16833    False
# Name: Fiscal Year, Length: 16834, dtype: bool

# %%
# We can use this list of booleans to make a smaller dataframe with only data from fiscal year 2017 as follows:
Income_Data[IsIt2017]
# Out:
#            Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0               A     45846      USD         2017            FY  2017-10-31
# 5             A18   1253413      USD         2017            FY  2017-12-31
# 13             AA    367153      USD         2017            FY  2017-12-31
# 20     AAC_delist    939324      USD         2017            FY  2017-12-31
# 29            AAL     68568      USD         2017            FY  2017-12-31
# ...           ...       ...      ...          ...           ...         ...
# 16805         ZUO    994625      USD         2017            FY  2018-01-31
# 16810        ZUUS  11795314      USD         2017            FY  2017-09-30
# 16817         ZVO    901866      USD         2017            FY  2017-12-31
# 16824        ZYNE    901704      USD         2017            FY  2017-12-31
# 16829        ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 5       2018-04-23    2020-04-09      66300808.0        71775893.0  ...
# 13      2018-02-26    2019-02-26     184000000.0       187000000.0  ...
# 20      2018-02-03    2019-04-15      23277444.0        23277444.0  ...
# 29      2018-02-21    2019-02-25     489164000.0       491692000.0  ...
# ...            ...           ...             ...               ...  ...
# 16805   2018-03-15    2020-03-31      26563000.0        26563000.0  ...
# 16810   2017-11-02    2018-12-20     105300000.0       105300000.0  ...
# 16817   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 16824   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 16829   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                      -38000000.0            -57000000.0
# 5                      581000000.0           -298000000.0
# 13                    -131000000.0           -104000000.0
# 20                       -116000.0                    NaN
# 29                    -836000000.0           -959000000.0
# ...                            ...                    ...
# 16805                     252000.0               252000.0
# 16810                          NaN                    NaN
# 16817                    1511000.0                    NaN
# 16824                     810705.0               519554.0
# 16829                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       803000000                      NaN
# 5                      3524000000                      NaN
# 13                     1468000000             -309000000.0
# 20                       27892000              -47015000.0
# 29                     3395000000                      NaN
# ...                           ...                      ...
# 16805                   -37826000                      NaN
# 16810                         925                      NaN
# 16817                    16619000               -8682000.0
# 16824                   -32012304                      0.0
# 16829                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 803000000                      -1.190000e+08
# 5                3524000000                      -1.285000e+09
# 13               1159000000                      -6.000000e+08
# 20                -19123000                       1.742000e+06
# 29               3395000000                      -2.113000e+09
# ...                     ...                                ...
# 16805             -37826000                      -1.551000e+06
# 16810                   925                                NaN
# 16817               7937000                       1.174000e+06
# 16824             -32012304                       0.000000e+00
# 16829               7494000                      -1.290000e+05
#
#        Income (Loss) from Continuing Operations  \
# 0                                     684000000
# 5                                    2174000000
# 13                                    559000000
# 20                                    -17381000
# 29                                   1282000000
# ...                                         ...
# 16805                                 -39377000
# 16810                                       925
# 16817                                   9111000
# 16824                                 -32012304
# 16829                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   684000000            684000000
# 5                                   NaN  2155000000           2155000000
# 13                                  NaN   217000000            217000000
# 20                                  NaN   -12873000            -12873000
# 29                                  NaN  1282000000           1282000000
# ...                                 ...         ...                  ...
# 16805                               NaN   -39377000            -39377000
# 16810                               NaN         925                  925
# 16817                               NaN     9111000              9111000
# 16824                               NaN   -32012304            -32012304
# 16829                               NaN     7365000              7365000
#
# [2881 rows x 28 columns]

# %%
# Or if we want to do this kind of filter in a single line:
Income_Data[Income_Data['Fiscal Year'] == 2017]
#Which is basically: 'I want the rows of Income_Data where the Income_Data Fiscal Year column is 2017.'
# Notice there are only 1,726 rows instead of 15,125
# Out:
#            Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0               A     45846      USD         2017            FY  2017-10-31
# 5             A18   1253413      USD         2017            FY  2017-12-31
# 13             AA    367153      USD         2017            FY  2017-12-31
# 20     AAC_delist    939324      USD         2017            FY  2017-12-31
# 29            AAL     68568      USD         2017            FY  2017-12-31
# ...           ...       ...      ...          ...           ...         ...
# 16805         ZUO    994625      USD         2017            FY  2018-01-31
# 16810        ZUUS  11795314      USD         2017            FY  2017-09-30
# 16817         ZVO    901866      USD         2017            FY  2017-12-31
# 16824        ZYNE    901704      USD         2017            FY  2017-12-31
# 16829        ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 5       2018-04-23    2020-04-09      66300808.0        71775893.0  ...
# 13      2018-02-26    2019-02-26     184000000.0       187000000.0  ...
# 20      2018-02-03    2019-04-15      23277444.0        23277444.0  ...
# 29      2018-02-21    2019-02-25     489164000.0       491692000.0  ...
# ...            ...           ...             ...               ...  ...
# 16805   2018-03-15    2020-03-31      26563000.0        26563000.0  ...
# 16810   2017-11-02    2018-12-20     105300000.0       105300000.0  ...
# 16817   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 16824   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 16829   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                      -38000000.0            -57000000.0
# 5                      581000000.0           -298000000.0
# 13                    -131000000.0           -104000000.0
# 20                       -116000.0                    NaN
# 29                    -836000000.0           -959000000.0
# ...                            ...                    ...
# 16805                     252000.0               252000.0
# 16810                          NaN                    NaN
# 16817                    1511000.0                    NaN
# 16824                     810705.0               519554.0
# 16829                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       803000000                      NaN
# 5                      3524000000                      NaN
# 13                     1468000000             -309000000.0
# 20                       27892000              -47015000.0
# 29                     3395000000                      NaN
# ...                           ...                      ...
# 16805                   -37826000                      NaN
# 16810                         925                      NaN
# 16817                    16619000               -8682000.0
# 16824                   -32012304                      0.0
# 16829                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 803000000                      -1.190000e+08
# 5                3524000000                      -1.285000e+09
# 13               1159000000                      -6.000000e+08
# 20                -19123000                       1.742000e+06
# 29               3395000000                      -2.113000e+09
# ...                     ...                                ...
# 16805             -37826000                      -1.551000e+06
# 16810                   925                                NaN
# 16817               7937000                       1.174000e+06
# 16824             -32012304                       0.000000e+00
# 16829               7494000                      -1.290000e+05
#
#        Income (Loss) from Continuing Operations  \
# 0                                     684000000
# 5                                    2174000000
# 13                                    559000000
# 20                                    -17381000
# 29                                   1282000000
# ...                                         ...
# 16805                                 -39377000
# 16810                                       925
# 16817                                   9111000
# 16824                                 -32012304
# 16829                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   684000000            684000000
# 5                                   NaN  2155000000           2155000000
# 13                                  NaN   217000000            217000000
# 20                                  NaN   -12873000            -12873000
# 29                                  NaN  1282000000           1282000000
# ...                                 ...         ...                  ...
# 16805                               NaN   -39377000            -39377000
# 16810                               NaN         925                  925
# 16817                               NaN     9111000              9111000
# 16824                               NaN   -32012304            -32012304
# 16829                               NaN     7365000              7365000
#
# [2881 rows x 28 columns]

# %%
# Let's order the stocks for financial year 2017 by net income.
# Within a DataFrame the rows can be ordered as follows:
Income_Data.sort_values(by=['Net Income'])
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 15300    UEC   7962592      USD         2018            FY  2018-07-31
# 15301    UEC   7962592      USD         2019            FY  2019-07-31
# 8882    LODE  11034293      USD         2017            FY  2017-12-31
# 8883    LODE  11034293      USD         2018            FY  2018-12-31
# 8309    KNDI  10656580      USD         2018            FY  2018-12-31
# ...      ...       ...      ...          ...           ...         ...
# 14766     TM   1217248      USD         2018            FY  2019-03-31
# 14767     TM   1217248      USD         2019            FY  2020-03-31
# 14768     TM   1217248      USD         2020            FY  2021-03-31
# 14765     TM   1217248      USD         2017            FY  2018-03-31
# 14769     TM   1217248      USD         2021            FY  2022-03-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 15300   2018-10-15    2020-10-29    1.282448e+08      1.282448e+08  ...
# 15301   2019-10-15    2020-10-29    1.758446e+08      1.758446e+08  ...
# 8882    2018-02-20    2020-03-30    8.225449e+06      8.225449e+06  ...
# 8883    2019-02-26    2020-03-30    1.192596e+07      1.192596e+07  ...
# 8309    2019-03-15    2020-04-28    5.118865e+07      5.118865e+07  ...
# ...            ...           ...             ...               ...  ...
# 14766   2019-06-21    2020-06-24    3.111306e+09      3.144947e+09  ...
# 14767   2020-06-24    2022-06-23    1.388735e+09      1.388766e+09  ...
# 14768   2021-06-24    2023-06-30    1.388735e+09      1.388766e+09  ...
# 14765   2018-06-25    2020-06-24    3.111306e+09      3.144947e+09  ...
# 14769   2022-06-23    2023-06-30    1.388735e+09      1.388766e+09  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 15300                -2.218468e+12          -2.724668e+12
# 15301                -3.785661e+12          -2.816850e+12
# 8882                 -1.698212e+12          -1.710390e+12
# 8883                 -2.080321e+12          -1.410389e+12
# 8309                 -1.747891e+13          -5.470390e+11
# ...                            ...                    ...
# 14766                 1.589740e+11           1.974170e+11
# 14767                 3.937120e+11           2.586910e+11
# 14768                 7.346060e+11          -4.753700e+10
# 14765                 2.205670e+11           1.519550e+11
# 14769                 9.948350e+11          -4.399700e+10
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 15300             -18532449000000            -1.696000e+09
# 15301             -18762674000000             1.595513e+12
# 8882              -10576178000000                      NaN
# 8883               -9480753000000                      NaN
# 8309              -19117254000000             2.119331e+13
# ...                           ...                      ...
# 14766               2626519000000            -3.410540e+11
# 14767               2792943000000                      NaN
# 14768               2932355000000                      NaN
# 14765               2620429000000                      NaN
# 14769               3990531000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 15300       -18534145000000                       7.075110e+11
# 15301       -17167161000000                       1.437200e+10
# 8882        -10576178000000                                NaN
# 8883         -9480753000000                                NaN
# 8309          2076055000000                      -7.770754e+12
# ...                     ...                                ...
# 14766         2285465000000                      -6.599440e+11
# 14767         2792943000000                      -6.818170e+11
# 14768         2932355000000                      -6.499760e+11
# 14765         2620429000000                      -5.044060e+11
# 14769         3990531000000                      -1.115918e+12
#
#        Income (Loss) from Continuing Operations  \
# 15300                           -17826634000000
# 15301                           -17152789000000
# 8882                            -10576178000000
# 8883                             -9480753000000
# 8309                             -5694699000000
# ...                                         ...
# 14766                             1985587000000
# 14767                             2111126000000
# 14768                             2282379000000
# 14765                             2586106000000
# 14769                             2874613000000
#
#        Net Extraordinary Gains (Losses)      Net Income  Net Income (Common)
# 15300                               NaN -17826634000000      -17826634000000
# 15301                               NaN -17152789000000      -17152789000000
# 8882                                NaN -10576178000000      -10576178000000
# 8883                                NaN  -9480753000000       -9480753000000
# 8309                                NaN  -5694699000000       -5694699000000
# ...                                 ...             ...                  ...
# 14766                               NaN   1882873000000        1882873000000
# 14767                               NaN   2036141000000        2036141000000
# 14768                               NaN   2245261000000        2245261000000
# 14765                               NaN   2493983000000        2493983000000
# 14769                               NaN   2850109000000        2850109000000
#
# [16834 rows x 28 columns]

# %%
# However, we wish to perform this for only the 2017 fiscal year. 
# Fortunately you can just put one operations in front of the other as follows:
Income_Data[Income_Data['Fiscal Year'] == 2017].sort_values(by=['Net Income'])
# It looks like AAPL and BRKA earned the most money that year, more than $40bn!
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 8882    LODE  11034293      USD         2017            FY  2017-12-31
# 7612     INO   9075872      USD         2017            FY  2017-12-31
# 3656    CPRX   2077094      USD         2017            FY  2017-12-31
# 14586   TEVA    616649      USD         2017            FY  2017-12-31
# 10028   MULN  10656564      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 3957     CTO  10656492      USD         2017            FY  2017-12-31
# 2368   BRK-A     71306      USD         2017            FY  2017-12-31
# 59      AAPL    111052      USD         2017            FY  2017-09-30
# 6959     HMC   1239537      USD         2017            FY  2018-03-31
# 14765     TM   1217248      USD         2017            FY  2018-03-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 8882    2018-02-20    2020-03-30    8.225449e+06      8.225449e+06  ...
# 7612    2018-03-14    2020-03-12    8.177749e+07      8.191802e+07  ...
# 3656    2018-03-14    2019-03-18    8.580249e+07      8.580249e+07  ...
# 14586   2018-02-01    2019-02-19    1.016000e+09      1.016000e+09  ...
# 10028   2018-04-02    2019-04-01             NaN               NaN  ...
# ...            ...           ...             ...               ...  ...
# 3957    2018-02-28    2020-03-06    1.662128e+07      1.673239e+07  ...
# 2368    2018-02-26    2019-02-25    3.289647e+06      3.289647e+06  ...
# 59      2017-11-03    2019-10-31    2.086897e+10      2.100677e+10  ...
# 6959    2018-03-31    2020-06-19    1.719962e+09      1.719962e+09  ...
# 14765   2018-06-25    2020-06-24    3.111306e+09      3.144947e+09  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 8882                 -1.698212e+12          -1.710390e+12
# 7612                  1.612974e+09           1.810518e+09
# 3656                  4.541630e+08                    NaN
# 14586                 3.040000e+08          -8.950000e+08
# 10028                -1.425631e+09          -1.189622e+09
# ...                            ...                    ...
# 3957                 -8.485151e+09          -8.523136e+09
# 2368                  5.142000e+09                    NaN
# 59                    2.745000e+09                    NaN
# 6959                  2.814150e+11           2.822100e+10
# 14765                 2.205670e+11           1.519550e+11
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 8882              -10576178000000                      NaN
# 7612                 -83029927000            -5.175845e+09
# 3656                 -18225473000            -1.869040e+08
# 14586                  4295000000            -2.267400e+10
# 10028                 -8702201000            -1.320848e+09
# ...                           ...                      ...
# 3957                   -740196000             3.800000e+04
# 2368                  23838000000                      NaN
# 59                    64089000000                      NaN
# 6959                1114973000000                      NaN
# 14765               2620429000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 8882        -10576178000000                                NaN
# 7612           -88205772000                                NaN
# 3656           -18412377000                                NaN
# 14586          -18379000000                       1.933000e+09
# 10028          -10023049000                                NaN
# ...                     ...                                ...
# 3957             -740158000                       2.248152e+10
# 2368            23838000000                       2.151500e+10
# 59              64089000000                      -1.573800e+10
# 6959          1114973000000                       1.366600e+10
# 14765         2620429000000                      -5.044060e+11
#
#        Income (Loss) from Continuing Operations  \
# 8882                            -10576178000000
# 7612                               -88205772000
# 3656                               -18412377000
# 14586                              -16449000000
# 10028                              -10023049000
# ...                                         ...
# 3957                                21741365000
# 2368                                45353000000
# 59                                  48351000000
# 6959                              1128639000000
# 14765                             2586106000000
#
#        Net Extraordinary Gains (Losses)      Net Income  Net Income (Common)
# 8882                                NaN -10576178000000      -10576178000000
# 7612                                NaN    -88205772000         -88205772000
# 3656                                NaN    -18412377000         -18412377000
# 14586                               NaN    -16265000000         -16525000000
# 10028                               NaN     -9913485000          -9913485000
# ...                                 ...             ...                  ...
# 3957                       1.997806e+10     41719424000          41719424000
# 2368                                NaN     44940000000          44940000000
# 59                                  NaN     48351000000          48351000000
# 6959                                NaN   1059337000000        1059337000000
# 14765                               NaN   2493983000000        2493983000000
#
# [2881 rows x 28 columns]

# %%
# Lets plot the distribution of net income for all american companies:
Income_Data['Net Income'].hist()
# Out:
# <Axes: >

# %%
# Plot graph with just 2017 FY data, logarithmic Y axis and more bins for greater resolution.
from matplotlib import pyplot as plt # Import plotting library
Income_Data[Income_Data['Fiscal Year'] == 2017]['Net Income'].hist(bins=100, log=True)
plt.title('USA Corporate Net Income for 2017 Histogram')
plt.xlabel('Value in USD')
plt.ylabel('Number of Instances')
print('Max value is: ', Income_Data[Income_Data['Fiscal Year'] == 2017]['Net Income'].max())
# Out:
# Max value is:  2493983000000

# %%
# Statistical data can be calculated with the dataframe .describe() function
Income_Data.describe()
# Out:
#            SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count  1.683400e+04  16834.000000    1.670400e+04      1.670300e+04
# mean   3.317826e+06   2019.151420    2.765314e+08      2.793873e+08
# std    4.288174e+06      1.430275    5.789589e+09      5.791041e+09
# min    1.800000e+01   2017.000000    5.000000e+00      5.000000e+00
# 25%    3.781870e+05   2018.000000    2.205900e+07      2.255841e+07
# 50%    9.217690e+05   2019.000000    5.083373e+07      5.166900e+07
# 75%    6.767687e+06   2020.000000    1.299971e+08      1.316482e+08
# max    1.244476e+07   2022.000000    6.769000e+11      6.769000e+11
#
#             Revenue  Cost of Revenue  Gross Profit  Operating Expenses  \
# count  1.552000e+04     1.366800e+04  1.366600e+04        1.681000e+04
# mean   2.941854e+10    -2.615934e+10  5.180422e+09       -7.433165e+09
# std    1.101195e+12     9.561572e+11  2.168092e+11        2.875491e+11
# min   -9.323700e+07    -9.219138e+13 -4.552151e+12       -2.350626e+13
# 25%    1.339305e+08    -1.858651e+09  8.027025e+07       -7.260000e+08
# 50%    7.351205e+08    -4.290435e+08  3.370850e+08       -2.103750e+08
# 75%    2.935914e+09    -6.917925e+07  1.209471e+09       -5.490050e+07
# max    1.124388e+14     4.205710e+08  2.024744e+13        6.801400e+07
#
#        Selling, General & Administrative  Research & Development  ...  \
# count                       1.596300e+04            7.566000e+03  ...
# mean                       -4.484442e+09           -2.502745e+09  ...
# std                         1.657333e+11            1.189001e+11  ...
# min                        -1.180142e+13           -1.008438e+13  ...
# 25%                        -4.247185e+08           -1.198655e+08  ...
# 50%                        -1.100070e+08           -4.140400e+07  ...
# 75%                        -2.444850e+07           -1.167900e+07  ...
# max                         1.573400e+07            6.581400e+07  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# count                 1.661100e+04           1.489900e+04
# mean                 -1.423810e+09          -6.598544e+08
# std                   1.418871e+11           3.734276e+10
# min                  -1.747891e+13          -2.816850e+12
# 25%                  -5.391650e+07          -7.500000e+07
# 50%                  -6.153000e+06          -1.271100e+07
# 75%                   3.300000e+04          -4.798190e+05
# max                   9.948350e+11           2.586910e+11
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# count                1.683400e+04             1.079700e+04
# mean                -2.940682e+09             1.806593e+09
# std                  2.812358e+11             2.051139e+11
# min                 -1.911725e+13            -1.537042e+12
# 25%                 -2.318275e+07            -4.095800e+07
# 50%                  1.454300e+07            -4.760000e+06
# 75%                  2.096215e+08             2.140000e+05
# max                  3.990531e+12             2.119331e+13
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# count          1.683400e+04                       1.391600e+04
# mean          -1.781969e+09                      -9.718011e+08
# std            2.344247e+11                       6.801936e+10
# min           -1.853414e+13                      -7.770754e+12
# 25%           -3.268300e+07                      -4.894000e+07
# 50%            7.306000e+06                      -3.857370e+06
# 75%            1.878612e+08                       3.900000e+04
# max            3.990531e+12                       7.075110e+11
#
#        Income (Loss) from Continuing Operations  \
# count                              1.683400e+04
# mean                              -2.535324e+09
# std                                2.321902e+11
# min                               -1.782663e+13
# 25%                               -3.234225e+07
# 50%                                6.223500e+06
# 75%                                1.544752e+08
# max                                2.874613e+12
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)
# count                      1.996000e+03  1.683400e+04         1.683400e+04
# mean                       9.791495e+07 -2.548359e+09        -2.658421e+09
# std                        9.552304e+08  2.320155e+11         2.348198e+11
# min                       -4.893000e+09 -1.782663e+13        -1.782663e+13
# 25%                       -6.000000e+06 -3.211000e+07        -3.280225e+07
# 50%                        0.000000e+00  5.996500e+06         5.411000e+06
# 75%                        2.298325e+07  1.512528e+08         1.497418e+08
# max                        2.126034e+10  2.850109e+12         2.850109e+12
#
# [8 rows x 22 columns]

# %%
# You can create new dataframes from filtered old dataframes, let's separate the 2017 fiscal year data to a new dataframe.
Income_Data_2017 = Income_Data[Income_Data['Fiscal Year'] == 2017]

# %%
Income_Data_2017.head(9)
# Out:
#         Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0            A     45846      USD         2017            FY  2017-10-31
# 5          A18   1253413      USD         2017            FY  2017-12-31
# 13          AA    367153      USD         2017            FY  2017-12-31
# 20  AAC_delist    939324      USD         2017            FY  2017-12-31
# 29         AAL     68568      USD         2017            FY  2017-12-31
# 34        AAMC    847094      USD         2017            FY  2017-12-31
# 39         AAN    441241      USD         2017            FY  2017-12-31
# 44        AAOI    671827      USD         2017            FY  2017-12-31
# 49        AAON    919501      USD         2017            FY  2017-12-31
#
#    Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0    2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 5    2018-04-23    2020-04-09      66300808.0        71775893.0  ...
# 13   2018-02-26    2019-02-26     184000000.0       187000000.0  ...
# 20   2018-02-03    2019-04-15      23277444.0        23277444.0  ...
# 29   2018-02-21    2019-02-25     489164000.0       491692000.0  ...
# 34   2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 39   2018-03-01    2019-02-14      70837000.0        72121000.0  ...
# 44   2018-02-28    2018-02-28      19097355.0        20139105.0  ...
# 49   2018-02-27    2019-02-28      52572496.0        53078734.0  ...
#
#     Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                   -38000000.0            -57000000.0
# 5                   581000000.0           -298000000.0
# 13                 -131000000.0           -104000000.0
# 20                    -116000.0                    NaN
# 29                 -836000000.0           -959000000.0
# 34                    1086000.0                    0.0
# 39                  -15122000.0            -18703000.0
# 44                   -2425000.0              -637000.0
# 49                     389000.0               298000.0
#
#     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                    803000000                      NaN             803000000
# 5                   3524000000                      NaN            3524000000
# 13                  1468000000             -309000000.0            1159000000
# 20                    27892000              -47015000.0             -19123000
# 29                  3395000000                      NaN            3395000000
# 34                    -6261000                      0.0              -6261000
# 39                   257571000              -17994000.0             239577000
# 44                    84526000                      NaN              84526000
# 49                    74537000                 -45000.0              74492000
#
#     Income Tax (Expense) Benefit, Net  \
# 0                       -1.190000e+08
# 5                       -1.285000e+09
# 13                      -6.000000e+08
# 20                       1.742000e+06
# 29                      -2.113000e+09
# 34                      -7.080000e+05
# 39                       5.295900e+07
# 44                      -1.057500e+07
# 49                      -1.999400e+07
#
#     Income (Loss) from Continuing Operations  \
# 0                                  684000000
# 5                                 2174000000
# 13                                 559000000
# 20                                 -17381000
# 29                                1282000000
# 34                                  -6969000
# 39                                 292536000
# 44                                  73951000
# 49                                  54498000
#
#     Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                NaN   684000000            684000000
# 5                                NaN  2155000000           2155000000
# 13                               NaN   217000000            217000000
# 20                               NaN   -12873000            -12873000
# 29                               NaN  1282000000           1282000000
# 34                               NaN    -6969000             -7175000
# 39                               NaN   292536000            292536000
# 44                               NaN    73951000             73951000
# 49                               NaN    54498000             54498000
#
# [9 rows x 28 columns]

# %%
Income_Data_2017.tail()
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 16805    ZUO    994625      USD         2017            FY  2018-01-31
# 16810   ZUUS  11795314      USD         2017            FY  2017-09-30
# 16817    ZVO    901866      USD         2017            FY  2017-12-31
# 16824   ZYNE    901704      USD         2017            FY  2017-12-31
# 16829   ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 16805   2018-03-15    2020-03-31      26563000.0        26563000.0  ...
# 16810   2017-11-02    2018-12-20     105300000.0       105300000.0  ...
# 16817   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 16824   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 16829   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 16805                     252000.0               252000.0
# 16810                          NaN                    NaN
# 16817                    1511000.0                    NaN
# 16824                     810705.0               519554.0
# 16829                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 16805                   -37826000                      NaN
# 16810                         925                      NaN
# 16817                    16619000               -8682000.0
# 16824                   -32012304                      0.0
# 16829                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 16805             -37826000                         -1551000.0
# 16810                   925                                NaN
# 16817               7937000                          1174000.0
# 16824             -32012304                                0.0
# 16829               7494000                          -129000.0
#
#        Income (Loss) from Continuing Operations  \
# 16805                                 -39377000
# 16810                                       925
# 16817                                   9111000
# 16824                                 -32012304
# 16829                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 16805                               NaN   -39377000            -39377000
# 16810                               NaN         925                  925
# 16817                               NaN     9111000              9111000
# 16824                               NaN   -32012304            -32012304
# 16829                               NaN     7365000              7365000
#
# [5 rows x 28 columns]

# %% [markdown]
# # Exercise 6 - Rudimentary stock filtering with Pandas
# ## Objectives:
# * To take the income statement data and the stock price data to make a rudimentary stock screener for price/earnings, price sales ratios, etc.
# * To view some agregate financial data visually to gain some intuition about the corporations in the stock market.
# * To practice what has been learnt so far in meeting the objectives
#
# ### Some bits of the code are missing, follow through and try and get it working

# %% [markdown]
# ### First lets get the stock data

# %%
#get csv data from simfin.com
import pandas as pd
import simfin as sf

# Set your API-key for downloading data.
sf.set_api_key('636bfaa6-75a6-4ec0-9461-432af1fb980b')

# Set the local directory where data-files are stored.
# The directory will be created if it does not already exist.
sf.set_data_dir('~/simfin_data/')

# Download the data from the SimFin server and load into a Pandas DataFrame.
incomeData = sf.load(dataset='income', variant='annual', market='us')
stockPrices = sf.load(dataset='shareprices', variant='daily', market='us')

# Print the first rows of the data.
print(incomeData.head())
print(stockPrices.head())
incomeData.head()

# Income_Data = pd.read_csv('us-income-annual.csv', delimiter=';')
# stock_prices = pd.read_csv('us-shareprices-daily.csv', delimiter=';')
# Out:
# Dataset "us-income-annual" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-shareprices-daily" on disk (0 days old).
# - Loading from disk ... Done!
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2017            FY  2017-10-31
# 1      A     45846      USD         2018            FY  2018-10-31
# 2      A     45846      USD         2019            FY  2019-10-31
# 3      A     45846      USD         2020            FY  2020-10-31
# 4      A     45846      USD         2021            FY  2021-10-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 1   2018-12-20    2020-12-18     321000000.0       325000000.0  ...
# 2   2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 3   2020-12-18    2022-12-21     309000000.0       312000000.0  ...
# 4   2021-12-17    2022-12-21     305000000.0       307000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -38000000.0            -57000000.0
# 1                   42000000.0            -37000000.0
# 2                  -22000000.0            -38000000.0
# 3                   -4000000.0            -70000000.0
# 4                   13000000.0            -79000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                   803000000                      NaN             803000000
# 1                   946000000                      NaN             946000000
# 2                   919000000                      NaN             919000000
# 3                   842000000                      NaN             842000000
# 4                  1360000000                      NaN            1360000000
#
#    Income Tax (Expense) Benefit, Net  \
# 0                       -119000000.0
# 1                       -630000000.0
# 2                        152000000.0
# 3                       -123000000.0
# 4                       -150000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 684000000                               NaN
# 1                                 316000000                               NaN
# 2                                1071000000                               NaN
# 3                                 719000000                               NaN
# 4                                1210000000                               NaN
#
#    Net Income  Net Income (Common)
# 0   684000000            684000000
# 1   316000000            316000000
# 2  1071000000           1071000000
# 3   719000000            719000000
# 4  1210000000           1210000000
#
# [5 rows x 28 columns]
#   Ticker  SimFinId        Date   Open    Low   High  Close  Adj. Close  \
# 0   GOOG        18  2017-08-10  45.88  45.31  45.96  45.36       45.36
# 1   GOOG        18  2017-08-11  45.40  45.28  45.89  45.72       45.72
# 2   GOOG        18  2017-08-14  46.13  45.91  46.23  46.13       46.13
# 3   GOOG        18  2017-08-15  46.21  45.99  46.33  46.11       46.11
# 4   GOOG        18  2017-08-16  46.26  46.17  46.63  46.35       46.35
#
#    Dividend    Volume  Shares Outstanding
# 0       NaN  34445920        1.385759e+10
# 1       NaN  23809160        1.385759e+10
# 2       NaN  20956560        1.385759e+10
# 3       NaN  17461400        1.385759e+10
# 4       NaN  19772080        1.385759e+10
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2017            FY  2017-10-31
# 1      A     45846      USD         2018            FY  2018-10-31
# 2      A     45846      USD         2019            FY  2019-10-31
# 3      A     45846      USD         2020            FY  2020-10-31
# 4      A     45846      USD         2021            FY  2021-10-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 1   2018-12-20    2020-12-18     321000000.0       325000000.0  ...
# 2   2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 3   2020-12-18    2022-12-21     309000000.0       312000000.0  ...
# 4   2021-12-17    2022-12-21     305000000.0       307000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -38000000.0            -57000000.0
# 1                   42000000.0            -37000000.0
# 2                  -22000000.0            -38000000.0
# 3                   -4000000.0            -70000000.0
# 4                   13000000.0            -79000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                   803000000                      NaN             803000000
# 1                   946000000                      NaN             946000000
# 2                   919000000                      NaN             919000000
# 3                   842000000                      NaN             842000000
# 4                  1360000000                      NaN            1360000000
#
#    Income Tax (Expense) Benefit, Net  \
# 0                       -119000000.0
# 1                       -630000000.0
# 2                        152000000.0
# 3                       -123000000.0
# 4                       -150000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 684000000                               NaN
# 1                                 316000000                               NaN
# 2                                1071000000                               NaN
# 3                                 719000000                               NaN
# 4                                1210000000                               NaN
#
#    Net Income  Net Income (Common)
# 0   684000000            684000000
# 1   316000000            316000000
# 2  1071000000           1071000000
# 3   719000000            719000000
# 4  1210000000           1210000000
#
# [5 rows x 28 columns]

# %%
# How big are these dataframes? How is the data stored? 
# print out the shape of both dataframes

print('Income data size is: ', incomeData.shape)
print('Stock price data size is: ', stockPrices.shape)
# Out:
# Income data size is:  (16841, 26)
# Stock price data size is:  (4843571, 9)

# %%
#print out the keys of the dataframes (which are the column headers)

print('Income keys are: ', incomeData.keys())
print('stock_prices keys are: ', stockPrices.keys())
# Out:
# Income keys are:  Index(['SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period', 'Publish Date',
#        'Restated Date', 'Shares (Basic)', 'Shares (Diluted)', 'Revenue',
#        'Cost of Revenue', 'Gross Profit', 'Operating Expenses',
#        'Selling, General & Administrative', 'Research & Development',
#        'Depreciation & Amortization', 'Operating Income (Loss)',
#        'Non-Operating Income (Loss)', 'Interest Expense, Net',
#        'Pretax Income (Loss), Adj.', 'Abnormal Gains (Losses)',
#        'Pretax Income (Loss)', 'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')
# stock_prices keys are:  Index(['SimFinId', 'Open', 'Low', 'High', 'Close', 'Adj. Close', 'Dividend',
#        'Volume', 'Shares Outstanding'],
#       dtype='object')

# %%
#Display the first 5 rows of the dataframes

incomeData.head(5)
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2017-10-31      45846      USD         2017            FY   2017-12-21
#        2018-10-31      45846      USD         2018            FY   2018-12-20
#        2019-10-31      45846      USD         2019            FY   2019-12-19
#        2020-10-31      45846      USD         2020            FY   2020-12-18
#        2021-10-31      45846      USD         2021            FY   2021-12-17
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# A      2017-10-31     2018-12-20     322000000.0       326000000.0
#        2018-10-31     2020-12-18     321000000.0       325000000.0
#        2019-10-31     2021-12-17     314000000.0       318000000.0
#        2020-10-31     2022-12-21     309000000.0       312000000.0
#        2021-10-31     2022-12-21     305000000.0       307000000.0
#
#                          Revenue  Cost of Revenue  ...  \
# Ticker Report Date                                 ...
# A      2017-10-31   4.472000e+09    -2.063000e+09  ...
#        2018-10-31   4.914000e+09    -2.234000e+09  ...
#        2019-10-31   5.163000e+09    -2.358000e+09  ...
#        2020-10-31   5.339000e+09    -2.502000e+09  ...
#        2021-10-31   6.319000e+09    -2.912000e+09  ...
#
#                     Non-Operating Income (Loss)  Interest Expense, Net  \
# Ticker Report Date
# A      2017-10-31                   -38000000.0            -57000000.0
#        2018-10-31                    42000000.0            -37000000.0
#        2019-10-31                   -22000000.0            -38000000.0
#        2020-10-31                    -4000000.0            -70000000.0
#        2021-10-31                    13000000.0            -79000000.0
#
#                     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# Ticker Report Date
# A      2017-10-31                    803000000                      NaN
#        2018-10-31                    946000000                      NaN
#        2019-10-31                    919000000                      NaN
#        2020-10-31                    842000000                      NaN
#        2021-10-31                   1360000000                      NaN
#
#                     Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# Ticker Report Date
# A      2017-10-31              803000000                       -119000000.0
#        2018-10-31              946000000                       -630000000.0
#        2019-10-31              919000000                        152000000.0
#        2020-10-31              842000000                       -123000000.0
#        2021-10-31             1360000000                       -150000000.0
#
#                     Income (Loss) from Continuing Operations  \
# Ticker Report Date
# A      2017-10-31                                  684000000
#        2018-10-31                                  316000000
#        2019-10-31                                 1071000000
#        2020-10-31                                  719000000
#        2021-10-31                                 1210000000
#
#                     Net Extraordinary Gains (Losses)  Net Income  \
# Ticker Report Date
# A      2017-10-31                                NaN   684000000
#        2018-10-31                                NaN   316000000
#        2019-10-31                                NaN  1071000000
#        2020-10-31                                NaN   719000000
#        2021-10-31                                NaN  1210000000
#
#                     Net Income (Common)
# Ticker Report Date
# A      2017-10-31             684000000
#        2018-10-31             316000000
#        2019-10-31            1071000000
#        2020-10-31             719000000
#        2021-10-31            1210000000
#
# [5 rows x 26 columns]

# %%
stockPrices.head(5)
# Out:
#                    SimFinId   Open    Low   High  Close  Adj. Close  Dividend  \
# Ticker Date
# A      2017-08-10     45846  59.35  58.22  59.50  58.57       55.98       NaN
#        2017-08-11     45846  58.70  58.69  59.70  59.33       56.70       NaN
#        2017-08-14     45846  59.80  59.55  60.04  59.62       56.98       NaN
#        2017-08-15     45846  59.70  59.11  59.88  59.38       56.75       NaN
#        2017-08-16     45846  62.15  60.76  62.42  62.14       59.39       NaN
#
#                     Volume  Shares Outstanding
# Ticker Date
# A      2017-08-10  2468724         322000000.0
#        2017-08-11  1511552         322000000.0
#        2017-08-14  2402982         322000000.0
#        2017-08-15  2871767         322000000.0
#        2017-08-16  6883325         322000000.0

# %% [markdown]
# ### Make a Market Cap series
# A lot of useful ratios commonly used to analyse companies depend on the Market Capitalization of the company, so we will add this to our dataframe first.
#
# Create a new dataframe which has all the income data as well as a market cap value, which will be the number of shares outstanding multiplied by the stock price.
#
# We will take the stock price at a relevant time for the income statement data, which should be around or just after the fiscal year reporting date.
#
# We will be using a previous fiscal year data for this exercise, where the 'Fiscal Year' series is 2017.

# %%
# See when the reporting data is usually made.
# To view a date in the series as a date object, instead of merely a string, use the pd.to_datetime() function.

# This date data has to be formatted this way for easy histogram plotting.
incomeData['Publish Date']=pd.to_datetime(incomeData['Publish Date'])

# Plot a histogram with a large number of bins to get a rough idea of when most reporting is done.
incomeData[incomeData['Fiscal Year'] == 2017]['Publish Date'].hist(bins=100)
# Out:
# <Axes: >

# %%
# Make a new dataframe of only the income data from 'Fiscal Year' == 2017.
incomeData_2017 = incomeData[incomeData['Fiscal Year'] == 2017]

# %%
# View the series of company tickers that exist for that fiscal year, and see how long the list is.
(incomeData[incomeData['Fiscal Year']==2017]['Ticker']).unique
# Out:
# <bound method Series.unique of 0                 A
# 5               A18
# 13               AA
# 20       AAC_delist
# 29              AAL
#             ...
# 16812           ZUO
# 16817          ZUUS
# 16824           ZVO
# 16831          ZYNE
# 16836          ZYXI
# Name: Ticker, Length: 2881, dtype: object>

# %%
# It appears as though most reporting is done just after the beginning of the year for these companies.
# Filter the stock price dataframe for the first of March of that year and make a new dataframe of that data. 
# print out the shape of the new dataframe. and use .head() to see it.

stockPrices_2018 = (stockPrices[stockPrices['Date'] == '2018-03-01'])
print('stock_prices_2018 dataframe shape is: ', stockPrices_2018.shape)
stockPrices_2018.head()
# Out:
# stock_prices_2018 dataframe shape is:  (3584, 11)
#      Ticker  SimFinId        Date    Open     Low    High   Close  Adj. Close  \
# 139    GOOG        18  2018-03-01   55.39   53.35   55.51   53.48       53.48
# 2259   ATVI       243  2018-03-01   73.16   71.52   73.42   72.01       69.10
# 3518    BLK       914  2018-03-01  548.60  527.03  549.02  535.58      464.37
# 4777   ADBE     14099  2018-03-01  210.32  204.45  210.68  206.03      206.03
# 6036    MMM     22219  2018-03-01  236.15  229.53  236.83  231.34      190.90
#
#       Dividend    Volume  Shares Outstanding
# 139        NaN  50318200        1.390595e+10
# 2259       NaN   8123915        7.586317e+08
# 3518       NaN    779735        1.607187e+08
# 4777       NaN   2632234        4.915785e+08
# 6036       NaN   3487126        5.955000e+08

# %%
# Notice the size of the list of tickersin the Income statement dataframe(1726) differs from the share prices dataframe(1901)
# In the real work we frequently deal with imperfect data. We will now cut down the data to make both dataframes correspond
# so that we can add out market cap column.

# %%
# Use the .isin() dataframe function to first cut down the share prices dataframe to only contain stocks that are in the 
# Income statement dataframe.
stockPrices_2018 = stockPrices_2018[stockPrices_2018['Ticker'].isin(incomeData_2017['Ticker'])]

# See the DataFrame
stockPrices_2018
# Out:
#         Ticker  SimFinId        Date    Open     Low    High   Close  \
# 139       GOOG        18  2018-03-01   55.39   53.35   55.51   53.48
# 2259      ATVI       243  2018-03-01   73.16   71.52   73.42   72.01
# 3518       BLK       914  2018-03-01  548.60  527.03  549.02  535.58
# 4777      ADBE     14099  2018-03-01  210.32  204.45  210.68  206.03
# 6036       MMM     22219  2018-03-01  236.15  229.53  236.83  231.34
# ...        ...       ...         ...     ...     ...     ...     ...
# 4813335   RCMT  12444453  2018-03-01    6.38    6.23    6.47    6.27
# 4818416   USDP  12444467  2018-03-01   11.15   11.10   11.31   11.10
# 4819849   BYRN  12444471  2018-03-01    1.50    1.50    1.50    1.50
# 4824502   NTIC  12444573  2018-03-01   11.50   11.01   11.65   11.12
# 4830437   HGBL  12444662  2018-03-01    0.39    0.39    0.43    0.43
#
#          Adj. Close  Dividend    Volume  Shares Outstanding
# 139           53.48       NaN  50318200        1.390595e+10
# 2259          69.10       NaN   8123915        7.586317e+08
# 3518         464.37       NaN    779735        1.607187e+08
# 4777         206.03       NaN   2632234        4.915785e+08
# 6036         190.90       NaN   3487126        5.955000e+08
# ...             ...       ...       ...                 ...
# 4813335        6.27       NaN      9098        1.219435e+07
# 4818416        6.27       NaN     15772        2.589860e+07
# 4819849        1.50       NaN         0        9.301413e+06
# 4824502       10.15       NaN      3448        9.074816e+06
# 4830437        0.43       NaN       535        2.848000e+07
#
# [2599 rows x 11 columns]

# %%
# Do the same in the opposite direction. 
incomeData_2017 = incomeData_2017[incomeData_2017['Ticker'].isin(stockPrices_2018['Ticker'])]
incomeData_2017
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2017            FY  2017-10-31
# 13        AA    367153      USD         2017            FY  2017-12-31
# 29       AAL     68568      USD         2017            FY  2017-12-31
# 34      AAMC    847094      USD         2017            FY  2017-12-31
# 44      AAOI    671827      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 16802    ZTS    378251      USD         2017            FY  2017-12-31
# 16807   ZUMZ     45730      USD         2017            FY  2018-01-31
# 16824    ZVO    901866      USD         2017            FY  2017-12-31
# 16831   ZYNE    901704      USD         2017            FY  2017-12-31
# 16836   ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 13      2018-02-26    2019-02-26     184000000.0       187000000.0  ...
# 29      2018-02-21    2019-02-25     489164000.0       491692000.0  ...
# 34      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 44      2018-02-28    2018-02-28      19097355.0        20139105.0  ...
# ...            ...           ...             ...               ...  ...
# 16802   2018-02-15    2018-02-15     489918000.0       493161000.0  ...
# 16807   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 16824   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 16831   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 16836   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                      -38000000.0            -57000000.0
# 13                    -131000000.0           -104000000.0
# 29                    -836000000.0           -959000000.0
# 34                       1086000.0                    0.0
# 44                      -2425000.0              -637000.0
# ...                            ...                    ...
# 16802                 -181000000.0           -175000000.0
# 16807                    -357000.0               495000.0
# 16824                    1511000.0                    NaN
# 16831                     810705.0               519554.0
# 16836                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       803000000                      NaN
# 13                     1468000000             -309000000.0
# 29                     3395000000                      NaN
# 34                       -6261000                      0.0
# 44                       84526000                      NaN
# ...                           ...                      ...
# 16802                  1544000000              -19000000.0
# 16807                    48403000                      NaN
# 16824                    16619000               -8682000.0
# 16831                   -32012304                      0.0
# 16836                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 803000000                      -1.190000e+08
# 13               1159000000                      -6.000000e+08
# 29               3395000000                      -2.113000e+09
# 34                 -6261000                      -7.080000e+05
# 44                 84526000                      -1.057500e+07
# ...                     ...                                ...
# 16802            1525000000                      -6.630000e+08
# 16807              48403000                      -2.160100e+07
# 16824               7937000                       1.174000e+06
# 16831             -32012304                       0.000000e+00
# 16836               7494000                      -1.290000e+05
#
#        Income (Loss) from Continuing Operations  \
# 0                                     684000000
# 13                                    559000000
# 29                                   1282000000
# 34                                     -6969000
# 44                                     73951000
# ...                                         ...
# 16802                                 862000000
# 16807                                  26802000
# 16824                                   9111000
# 16831                                 -32012304
# 16836                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   684000000            684000000
# 13                                  NaN   217000000            217000000
# 29                                  NaN  1282000000           1282000000
# 34                                  NaN    -6969000             -7175000
# 44                                  NaN    73951000             73951000
# ...                                 ...         ...                  ...
# 16802                               NaN   864000000            864000000
# 16807                               NaN    26802000             26802000
# 16824                               NaN     9111000              9111000
# 16831                               NaN   -32012304            -32012304
# 16836                               NaN     7365000              7365000
#
# [2599 rows x 28 columns]

# %%
# We have lost some rows in our dataframes in keeping only common stock tickers. Sometimes we loose things, such is life.
# Arrange both income and stock price dataframes alphabetically so the rows correspond.
# Create a new dataframe called stock_data_2018 as a copy of Income_Data_2018 (we will be adding some columns soon)
# Create a market cap column in stock_data_2018 by multiplying the open price with the number of shares outstanding,
# use .values to do the multiplication.

stockPrices_2018 = stockPrices_2018.sort_values(by=['Ticker'])
incomeData_2018 = incomeData_2017.sort_values(by=['Ticker'])

# Make the stock_data DataFrame from the Income Data and add a Market Cap series.
stockData_2018 = incomeData_2017
stockData_2018['Market Cap'] = incomeData_2017['Shares (Diluted)'].values * stockPrices_2018['Open'].values

# %%
# Take a look at the distribution of Market Caps in the stock market with a histogram.
# use a large number of hisogram bins and a log scale, this will enable you to view the data better.
# You will see that there are many at the low end, and very few super large corporations in America

stockData_2018['Market Cap'].hist(bins=100, log=True)
# Try to format this graph yourself with title, axis labels and so on.
# Out:
# <Axes: >

# %% [markdown]
# ## Using market cap, make a price/earnings Series in the Stock_Data DataFrame

# %%
# Define a new column for price/earnings
# and view the histogram for it


stockData_2018['Price/Earnings'] = stockData_2018['Market Cap'].values/stockData_2018['Net Income'].values
stockData_2018[stockData_2018['Price/Earnings']==np.NaN]['Price/Earnings']

#stockData_2018['Price/Earnings'].hist(bins=100, log=True)
# Notice that there are values all over the place 
# some p/e ratios are above 10,000! and there are many below 0 (they don't earn eanything!)
# Out:
# /var/folders/v5/l6r2n01n49jbz5242br98j3m0000gn/T/ipykernel_53479/585395680.py:5: RuntimeWarning: divide by zero encountered in divide
#   stockData_2018['Price/Earnings'] = stockData_2018['Market Cap'].values/stockData_2018['Net Income'].values
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 6
#       1 # Define a new column for price/earnings
#       2 # and view the histogram for it
#       5 stockData_2018['Price/Earnings'] = stockData_2018['Market Cap'].values/stockData_2018['Net Income'].values
# ----> 6 stockData_2018[stockData_2018['Price/Earnings']==np.NaN]['Price/Earnings']
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Filter your stock data
# Filter your stock data for a reasonable range of price/earnings ratios of companies you might invest in, say from 5 to 50, and look at the histogram of the resulting companies.
# You may need to use a boolean list with some logic to do so.

# %%
# Make the same histogram as before for p/e but this time after a filter by p/e above 5 and below 50.
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (????['Price/Earnings'] <= 50))]['Price/Earnings'].hist(

# %%
#View a histogram of a different column, say market cap, but with the same p/e filter
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (stock_data_2018['Price/Earnings'] <= 50))]['???'].hist(log=True)

# %%
# You can also plot scatter plots with Pandas, here is an example scatter plot of p/e with Market cap.
# It appears as though the largest companies have a p/e around 20-35, for the rest nearly any p/e can be found.
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (stock_data_2018['Price/Earnings'] <= 50))].plot.scatter(x = 'Price/Earnings', y = 'Market Cap')

# %% [markdown]
# End of Exercise 6. With the tools you have you are now able to use Pandas to filter through fundamental stock data. There are a myriad of ratios and analyses that may be carried out to filter through stocks to find good investments. In the next chapter we will learn some basics of Machine Learning to try and sift through data and find useful infomation.

# %% [markdown]
# # Pandas Data Reader

# %%
import pandas as pd
import pandas_datareader.data as pdr
from matplotlib import pyplot as plt

start = pd.to_datetime('2019-05-01')
end = pd.to_datetime('2020-05-01')
tickerData = pdr.DataReader('SPY', 'yahoo', start, end);

plt.plot(tickerData['Open']);
plt.grid()
plt.xlabel('Date')
plt.ylabel('SPY value')
# Out:
# C:\Users\G50\miniconda3\envs\tensorflow\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# Text(0, 0.5, 'SPY value')

# %%
tickerData
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-05-01  294.950012  291.799988  294.720001  291.809998   71671900.0
# 2019-05-02  292.700012  289.519989  291.679993  291.179993   65030200.0
# 2019-05-03  294.339996  291.299988  292.820007  294.029999   56543700.0
# 2019-05-06  293.309998  288.899994  289.250000  292.820007  107198100.0
# 2019-05-07  290.809998  285.809998  290.149994  287.929993  144729900.0
# ...                ...         ...         ...         ...          ...
# 2020-04-27  288.269989  284.619995  285.119995  287.049988   77896600.0
# 2020-04-28  291.399994  285.399994  291.019989  285.730011  105270000.0
# 2020-04-29  294.880005  290.410004  291.529999  293.209991  118745600.0
# 2020-04-30  293.320007  288.589996  291.709991  290.480011  122901700.0
# 2020-05-01  290.660004  281.519989  285.309998  282.790009  125180000.0
#
#              Adj Close
# Date
# 2019-05-01  282.375183
# 2019-05-02  281.765503
# 2019-05-03  284.523407
# 2019-05-06  283.352539
# 2019-05-07  278.620605
# ...                ...
# 2020-04-27  283.444672
# 2020-04-28  282.141235
# 2020-04-29  289.527283
# 2020-04-30  286.831604
# 2020-05-01  279.238159
#
# [254 rows x 6 columns]

# %% [markdown]
# ### iloc and loc

# %%
# .iloc[] selects rows like a list

# %%
tickerData.iloc[-5:] #last 5
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-04-27  288.269989  284.619995  285.119995  287.049988   77896600.0
# 2020-04-28  291.399994  285.399994  291.019989  285.730011  105270000.0
# 2020-04-29  294.880005  290.410004  291.529999  293.209991  118745600.0
# 2020-04-30  293.320007  288.589996  291.709991  290.480011  122901700.0
# 2020-05-01  290.660004  281.519989  285.309998  282.790009  125180000.0
#
#              Adj Close
# Date
# 2020-04-27  283.444672
# 2020-04-28  282.141235
# 2020-04-29  289.527283
# 2020-04-30  286.831604
# 2020-05-01  279.238159

# %%
tickerData.iloc[:5] #first 5
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-05-01  294.950012  291.799988  294.720001  291.809998   71671900.0
# 2019-05-02  292.700012  289.519989  291.679993  291.179993   65030200.0
# 2019-05-03  294.339996  291.299988  292.820007  294.029999   56543700.0
# 2019-05-06  293.309998  288.899994  289.250000  292.820007  107198100.0
# 2019-05-07  290.809998  285.809998  290.149994  287.929993  144729900.0
#
#              Adj Close
# Date
# 2019-05-01  282.375183
# 2019-05-02  281.765503
# 2019-05-03  284.523407
# 2019-05-06  283.352539
# 2019-05-07  278.620605

# %%
tickerData.iloc[207] # row 207
# Out:
# High         3.181100e+02
# Low          3.107000e+02
# Open         3.141800e+02
# Close        3.115000e+02
# Volume       1.947738e+08
# Adj Close    3.057895e+02
# Name: 2020-02-26 00:00:00, dtype: float64

# %%
# .loc[] selects rows using the index. With Timeseries data like this, the index is a date, not a number.
tickerData.loc['2019-05-01']
# Out:
# High         2.949500e+02
# Low          2.918000e+02
# Open         2.947200e+02
# Close        2.918100e+02
# Volume       7.167190e+07
# Adj Close    2.823752e+02
# Name: 2019-05-01 00:00:00, dtype: float64

# %%
tickerData.loc[tickerData.index>'2020-01-01']['Close'].plot()
